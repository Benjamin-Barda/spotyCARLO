# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.set_style('ticks')

# %%
metal_df = pd.read_csv("data//csvs//metal_cleaned.csv")
rap_df = pd.read_csv("data//csvs//rap_cleaned.csv")
classic_df = pd.read_csv("data//csvs//classic_cleaned.csv")
jazz_df = pd.read_csv("data//csvs//jazz_cleaned.csv")

# %%
feat = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

# %% [markdown]
# the dataframes are already cleaned so we can go ahead and create some plots

# %%
fig, ax = plt.subplots(4, len(feat), figsize=(25,10))

for i in range(len(feat)): 
    sns.histplot(data = metal_df, x = feat[i], stat='density', ax = ax[0][i])
for i in range(len(feat)): 
    sns.histplot(data = rap_df, x = feat[i], stat='density', ax = ax[1][i])
for i in range(len(feat)): 
    sns.histplot(data = jazz_df, x = feat[i], stat='density', ax = ax[2][i])
for i in range(len(feat)): 
    sns.histplot(data = classic_df, x = feat[i], stat='density', ax = ax[3][i])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\myStuff\spotyCARLO\firstAnalysis.ipynb Cell 5' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/myStuff/spotyCARLO/firstAnalysis.ipynb#ch0000005?line=3'>4</a>     sns.histplot(data = metal_df, x = feat[i], stat='density', ax = ax[0][i])
#       <a href='vscode-notebook-cell:/d%3A/myStuff/spotyCARLO/firstAnalysis.ipynb#ch0000005?line=4'>5</a> for i in range(len(feat)):
# ----> <a href='vscode-notebook-cell:/d%3A/myStuff/spotyCARLO/firstAnalysis.ipynb#ch0000005?line=5'>6</a>     sns.histplot(data = rap_df, x = feat[i], stat='density', ax = ax[1][i])
#       <a href='vscode-notebook-cell:/d%3A/myStuff/spotyCARLO/firstAnalysis.ipynb#ch0000005?line=6'>7</a> for i in range(len(feat)):
#       <a href='vscode-notebook-cell:/d%3A/myStuff/spotyCARLO/firstAnalysis.ipynb#ch0000005?line=7'>8</a>     sns.histplot(data = jazz_df, x = feat[i], stat='density', ax = ax[2][i])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:1462, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1450'>1451</a> estimate_kws = dict(
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1451'>1452</a>     stat=stat,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1452'>1453</a>     bins=bins,
#    (...)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1456'>1457</a>     cumulative=cumulative,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1457'>1458</a> )
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1459'>1460</a> if p.univariate:
# -> <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1461'>1462</a>     p.plot_univariate_histogram(
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1462'>1463</a>         multiple=multiple,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1463'>1464</a>         element=element,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1464'>1465</a>         fill=fill,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1465'>1466</a>         shrink=shrink,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1466'>1467</a>         common_norm=common_norm,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1467'>1468</a>         common_bins=common_bins,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1468'>1469</a>         kde=kde,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1469'>1470</a>         kde_kws=kde_kws,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1470'>1471</a>         color=color,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1471'>1472</a>         legend=legend,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1472'>1473</a>         estimate_kws=estimate_kws,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1473'>1474</a>         line_kws=line_kws,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1474'>1475</a>         **kwargs,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1475'>1476</a>     )
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1477'>1478</a> else:
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1479'>1480</a>     p.plot_bivariate_histogram(
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1480'>1481</a>         common_bins=common_bins,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1481'>1482</a>         common_norm=common_norm,
#    (...)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1491'>1492</a>         **kwargs,
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=1492'>1493</a>     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\distributions.py:565, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=559'>560</a> if element == "bars":
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=560'>561</a>
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=561'>562</a>     # Use matplotlib bar plotting
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=563'>564</a>     plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=564'>565</a>     artists = plot_func(
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=565'>566</a>         hist["edges"],
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=566'>567</a>         hist["heights"] - bottom,
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=567'>568</a>         hist["widths"],
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=568'>569</a>         bottom,
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=569'>570</a>         align="edge",
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=570'>571</a>         **artist_kws,
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=571'>572</a>     )
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=572'>573</a>     for bar in artists:
#     <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/seaborn/distributions.py?line=573'>574</a>         if self.data_variable == "x":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/__init__.py?line=1408'>1409</a> @functools.wraps(func)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/__init__.py?line=1409'>1410</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/__init__.py?line=1410'>1411</a>     if data is None:
# -> <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/__init__.py?line=1411'>1412</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/__init__.py?line=1413'>1414</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/__init__.py?line=1414'>1415</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/__init__.py?line=1415'>1416</a>                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_axes.py:2409, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_axes.py?line=2406'>2407</a>     elif orientation == 'horizontal':
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_axes.py?line=2407'>2408</a>         r.sticky_edges.x.append(l)
# -> <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_axes.py?line=2408'>2409</a>     self.add_patch(r)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_axes.py?line=2409'>2410</a>     patches.append(r)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_axes.py?line=2411'>2412</a> if xerr is not None or yerr is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:2363, in _AxesBase.add_patch(self, p)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_base.py?line=2360'>2361</a> if p.get_clip_path() is None:
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_base.py?line=2361'>2362</a>     p.set_clip_path(self.patch)
# -> <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_base.py?line=2362'>2363</a> self._update_patch_limits(p)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_base.py?line=2363'>2364</a> self._children.append(p)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_base.py?line=2364'>2365</a> p._remove_method = self._children.remove
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:2397, in _AxesBase._update_patch_limits(self, patch)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_base.py?line=2394'>2395</a>         updatey = False
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_base.py?line=2395'>2396</a> trf_to_data = patch_trf - self.transData
# -> <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_base.py?line=2396'>2397</a> xys = trf_to_data.transform(vertices)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/axes/_base.py?line=2397'>2398</a> self.update_datalim(xys, updatex=updatex, updatey=updatey)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:1503, in Transform.transform(self, values)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=1499'>1500</a> values = values.reshape((-1, self.input_dims))
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=1501'>1502</a> # Transform the values
# -> <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=1502'>1503</a> res = self.transform_affine(self.transform_non_affine(values))
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=1504'>1505</a> # Convert the result back to the shape of the input values.
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=1505'>1506</a> if ndim == 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:2419, in CompositeGenericTransform.transform_affine(self, points)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=2416'>2417</a> def transform_affine(self, points):
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=2417'>2418</a>     # docstring inherited
# -> <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=2418'>2419</a>     return self.get_affine().transform(points)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=2443'>2444</a>     return self._b.get_affine()
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=2444'>2445</a> else:
# -> <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=2445'>2446</a>     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=2446'>2447</a>                            self._a.get_affine().get_matrix()))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:1914, in Affine2D.__init__(self, matrix, **kwargs)
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=1910'>1911</a> if matrix is None:
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=1911'>1912</a>     # A bit faster than np.identity(3).
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=1912'>1913</a>     matrix = IdentityTransform._mtx.copy()
# -> <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=1913'>1914</a> self._mtx = matrix.copy()
#    <a href='file:///c%3A/Users/barda/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/matplotlib/transforms.py?line=1914'>1915</a> self._invalid = 0
#
# KeyboardInterrupt:
